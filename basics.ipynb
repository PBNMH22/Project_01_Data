# %%
import matplotlib as mt

# %%
import matplotlib.pyplot as plt

# %%
squares=[]
for num in range(1,6):
    num=num**2
    squares.append(num)
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
plt.plot(squares)
plt.show()

# %%
plt.plot(squares,linewidth=5)
plt.title('Square Numbers',fontsize=24)
plt.xlabel('Numbers',fontsize=14)
plt.ylabel('squares',fontsize=14)
plt.tick_params(axis='both',labelsize=14)
plt.show()

# %%
numbers=[1,2,3,4,5]
cubes=[num**3 for num in numbers]

# %%
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
plt.plot(numbers,cubes,linewidth=4)

# %%
plt.plot(numbers,cubes,linewidth=4,color='Green')
plt.title('Cube of Numbers',fontsize=18,color='Red')
plt.xlabel('Numbers',fontsize=14)
plt.ylabel('cubes',fontsize=14)
plt.tick_params(axis='Deepak',labelsize=15)
plt.show()

# %%
plt.scatter(4,6,s=200)

plt.show()

# %%
plt.scatter(numbers,squares,s=100,c=squares,cmap=plt.cm.Reds,edgecolors='none')
plt.title('Scatter Plot',fontsize=18,color='indigo')
plt.xlabel('Numbers',fontsize=12)
plt.ylabel('Squares',fontsize=14)
plt.savefig('Scatter Plot.png')

# %% [markdown]
# # Creating random walk

# %%
from random import choice
# to create a random walk we will create RandomWalk() class first

class RandomWalk():
    def __init__(self,num_points=5000):
        self.num_points=num_points
        self.x_values=[0]
        self.y_values=[0]
    
    def fill_walk(self):
        '''Calculate all the points in the walk'''
        while len(self.x_values) < self.num_points:
            x_direction=choice([1,-1])
            x_distance=choice([0,1,2,3,4])
            x_step=x_direction*x_distance
            
            y_direction=choice([1,-1])
            y_distance=choice([0,1,2,3,4])
            y_step=y_direction*y_distance
            
            if x_step==0 and y_step==0:
                continue
            # Calculate the next x and y values
            
            next_x=self.x_values[-1]+x_step
            next_y=self.y_values[-1]+y_step
            
            self.x_values.append(next_x)
            self.y_values.append(next_y)

# %%
rw=RandomWalk()
rw.fill_walk()
plt.scatter(rw.x_values,rw.y_values,s=10)
plt.show()
plt.savefig('Random_Walk1.png')

# %%
rw=RandomWalk()
rw.fill_walk()
plt.scatter(rw.x_values,rw.y_values,s=10)
plt.show()
plt.savefig('Random_Walk2.png')

# %%
rw=RandomWalk()
rw.fill_walk()
plt.scatter(rw.x_values,rw.y_values,s=15)
plt.show()
plt.savefig('Random_Walk4.pdf')
